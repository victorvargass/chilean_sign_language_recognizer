# %%
from __future__ import division
import numpy as np
import os
from os import listdir
from os.path import join
from PIL import Image
import torch 
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler
from torch.utils import data
from torchvision import transforms, models, datasets
import pandas as pd
import cv2
from matplotlib import pyplot as plt
import matplotlib
import random
# %matplotlib inline
from timeit import default_timer as timer
import hiddenlayer as hl

# %%
class Signs_Dataset(data.Dataset):
    'Characterizes a dataset for PyTorch'
    def __init__(self, list_IDs, labels, img_path, transform = None):
        'Initialization'
        self.labels = labels
        self.list_IDs = list_IDs
        self.transform = transform
        self.img_path = img_path

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.list_IDs)
    
    def __getclasses__():
        return list('ABCDEFHIKLMNOPQRTUVWY')

    def __getitem__(self, index):
        'Generates one sample of data'
        # Select sample
        ID = self.list_IDs[index]
        # Load data and get 
        image = Image.open(join(self.img_path,ID))
        #X = torch.tensor((np.asarray(image).T/255.).astype('float32'))
        #X = image
        #image = np.asarray(image)
        if self.transform:
            X = self.transform(image)
            
        y = self.labels[ID]
        return X, y

# %%
"""
Red tipo lenet para partir
"""
class LeNet5(torch.nn.Module):
    
    def __init__(self, n_output=2):
        super(LeNet5, self).__init__()
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=6, kernel_size=3, stride=1)
        self.conv2 = torch.nn.Conv2d(in_channels=6, out_channels=16, kernel_size=3, stride=1)
        self.adapool  = torch.nn.AdaptiveMaxPool2d((5, 5))
        self.fc1 = torch.nn.Linear(in_features=16*5*5, out_features=120)
        self.fc2 = torch.nn.Linear(in_features=120, out_features=84)
        self.fc3 = torch.nn.Linear(in_features=84, out_features=n_output)
        self.activation = torch.nn.ReLU()
    
    def forward(self, x):
        z = self.activation(self.conv1(x))
        z = F.max_pool2d(z, 2)
        z = self.activation(self.conv2(z))
        #z = F.max_pool2d(z, 2)
        z = self.adapool(z)
        z = z.view(z.size(0), -1)
        z = self.activation(self.fc1(z))
        z = self.activation(self.fc2(z))
        y = self.fc3(z)
        return y
    
    def save_weights(self, path):
        torch.save(self.state_dict(), path)
    
    def load_weights(self, path):
        self.load_state_dict(torch.load(path))

# %%
class AlexNet(torch.nn.Module):

    def __init__(self, n_output=21):
        super(AlexNet, self).__init__()
        self.features = torch.nn.Sequential(
            torch.nn.Conv2d(3, 64, kernel_size=3, stride=1),
            torch.nn.ReLU(inplace=True),
            torch.nn.MaxPool2d(kernel_size=3, stride=2),
            torch.nn.Conv2d(64, 192, kernel_size=5, padding=2),
            torch.nn.ReLU(inplace=True),
            torch.nn.MaxPool2d(kernel_size=3, stride=2),
            torch.nn.Conv2d(192, 384, kernel_size=3, padding=1),
            torch.nn.ReLU(inplace=True),
            torch.nn.Conv2d(384, 256, kernel_size=3, padding=1),
            torch.nn.ReLU(inplace=True),
            torch.nn.Conv2d(256, 256, kernel_size=3, padding=1),
            torch.nn.ReLU(inplace=True),
            torch.nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = torch.nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = torch.nn.Sequential(
            torch.nn.Dropout(),
            torch.nn.Linear(256 * 6 * 6, 4096),
            torch.nn.ReLU(inplace=True),
            torch.nn.Dropout(),
            torch.nn.Linear(4096, 4096),
            torch.nn.ReLU(inplace=True),
            torch.nn.Linear(4096, n_output),
        )

    def forward(self, x):
        #print(x.shape) torch.Size([1, 3, 224, 224])
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), 256 * 6 * 6)
        x = self.classifier(x)
        return x
    
    def save_weights(self, path):
        torch.save(self.state_dict(), path)
    
    def load_weights(self, path):
        self.load_state_dict(torch.load(path))

# %%
# Image transformations
image_transforms = {
    'train': transforms.Compose([
                transforms.ColorJitter(brightness=0.2, contrast=0.5, saturation=0.2, hue=0),
                #transforms.Grayscale(3),
                transforms.RandomAffine(degrees = 10, translate=(0.2,0), fillcolor=(255,255,255)),
                transforms.Resize(size=(224, 224)),
                #transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
                transforms.RandomHorizontalFlip(),
                #transforms.CenterCrop(size=224),  # Image net standards
                transforms.ToTensor(),
                transforms.Normalize
                            (mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
                transforms.Resize(size=(224, 224)),
                #transforms.CenterCrop(size=224),
                transforms.ToTensor(),
                transforms.Normalize
                            (mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
        ]),
}

# %%
def imshow_tensor(image, ax=None, title=None):
    """Imshow for Tensor."""

    if ax is None:
        fig, ax = plt.subplots()

    # Set the color channel as the third dimension
    image = image.numpy().transpose((1, 2, 0))

    # Reverse the preprocessing steps
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Clip the image pixel values
    image = np.clip(image, 0, 1)

    ax.imshow(image)
    plt.axis('off')

    return ax, image


ex_img = Image.open('balanced/I2047.jpg')
plt.imshow(ex_img)

t = image_transforms['train']
plt.figure(figsize=(24, 24))

for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    _ = imshow_tensor(t(ex_img), ax=ax)

plt.tight_layout()

# %%
#Datasets

img_dataset_path = 'balanced/'
partition = {'train':[], 'validation':[], 'test':[]}
labels = {}
classes = list('ABCDEFHIKLMNOPQRTUVWY')

files = os.listdir(img_dataset_path)
random.shuffle(files)

c = 0
N = len(files)
#print(N)
for name in files:
    if(c>=N*0.2):
        partition['train'].append(name)
    if(c<N*0.2):
        if(c<=N*0.1):
            partition['validation'].append(name)
        else:
            #print('Test: ', name)
            partition['test'].append(name)
    labels[name] = classes.index(name[0])

    c = c + 1


# Parameters
params = {'batch_size': 64, 'shuffle' : True}


# Generators
training_set = Signs_Dataset(partition['train'], labels, 
                             img_path = img_dataset_path, transform=image_transforms['train'])
sign_loader_train = data.DataLoader(training_set, **params)
print("Training dataloader done")

validation_set = Signs_Dataset(partition['validation'], labels, 
                               img_path = img_dataset_path, transform=image_transforms['valid'])
sign_loader_validation = data.DataLoader(validation_set, **params)
print("Validation dataloader done")

test_set = Signs_Dataset(partition['test'], labels,
                         img_path = img_dataset_path, transform=image_transforms['valid'])
sign_loader_test = data.DataLoader(test_set, **params)
print("Testing dataloader done")

sign_loaders = [sign_loader_train, sign_loader_validation, sign_loader_test]
# Out:
# Training dataloader done
# Validation dataloader done
# Testing dataloader done
# Distribution train dataset: {0: 9, 1: 10, 2: 11, 3: 9, 4: 7, 5: 7, 6: 12, 7: 5, 8: 5, 9: 6, 10: 4, 11: 7, 12: 7, 13: 4, 14: 5, 15: 8, 16: 9, 17: 6, 18: 10, 19: 3, 20: 11}
# Distribution valid dataset: {0: 1, 2: 1, 3: 2, 6: 1, 7: 1, 9: 1, 11: 1, 12: 1, 13: 1, 14: 2, 15: 1, 16: 1, 17: 2, 19: 2, 20: 2}
# Distribution test dataset: {16: 1, 1: 2, 2: 1, 3: 1, 4: 1, 5: 2, 7: 2, 8: 2, 18: 1, 11: 3, 13: 4}

# %%
model = LeNet5(n_output=21) 
#print(model)
loss = torch.nn.CrossEntropyLoss()
use_gpu = True
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
if use_gpu:
    model = model.cuda()

# %%
model = AlexNet(n_output=21) 
loss = torch.nn.CrossEntropyLoss()
use_gpu = True
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
if use_gpu:
    model = model.cuda()

# %%
epochs = 30
h = hl.History()
c = hl.Canvas()

for epoch in range(epochs):
    # Entrenamiento
    train_loss = 0.0
    for image_batch, label_batch in sign_loaders[0]:
        optimizer.zero_grad()
        if use_gpu:
            image_batch = image_batch.cuda()
            label_batch = label_batch.cuda()
        predictions = model.forward(image_batch)
        loss_batch = loss(predictions, label_batch)        
        loss_batch.backward()
        optimizer.step()
        train_loss += loss_batch.detach().cpu()/sign_loaders[0].__len__()
    #print("{0}, {1}".format(epoch, train_loss/sign_loaders[0].__len__()))
    h.log(epoch, train_loss=train_loss)
    
    # Validación
    validation_loss = 0.0
    for image_batch, label_batch in sign_loaders[1]:
        if use_gpu:
            image_batch = image_batch.cuda()
            label_batch = label_batch.cuda()
        predictions = model.forward(image_batch)
        loss_batch = loss(predictions, label_batch)    
        validation_loss += loss_batch.detach().cpu()/sign_loaders[1].__len__()
    h.log(epoch, validation_loss=validation_loss)
    with c: # So that they render together
        #c.draw_plot([h["train_loss"], h["validation_loss"]])
        c.draw_plot([h["train_loss"], h["validation_loss"]],["Train loss", "Validation loss"])
    print("Epoch %d, T loss %0.4f, V loss %0.4f" %(epoch, train_loss, validation_loss))

# %%
results_path = "results"
experiment_name = "/alphabet_lenet" + str(epochs)

weights_file_path     = results_path + experiment_name + experiment_name + ".weights"
c_matrix_file_path    = results_path + experiment_name + experiment_name + ".png"

if not os.path.exists(results_path + experiment_name):
    os.makedirs(results_path + experiment_name)
model.save_weights(weights_file_path)

# %%
#Load weights when kernel deads
epochs = 100
results_path = "results"
experiment_name = "/alphabet_lenet" + str(epochs)

weights_file_path     = results_path + experiment_name + experiment_name + ".weights"
c_matrix_file_path    = results_path + experiment_name + experiment_name + ".png"

model.load_weights(weights_file_path)

# %%
sign_loaders = [sign_loader_train, sign_loader_validation, sign_loader_test]
#sign_loader_selected = sign_loaders[2]
sign_loader_selected = sign_loader_american

#print(sign_loader_selected.__len__())
#predictions_test = np.zeros(shape=(sign_loader_selected.__len__(), 21))
predictions_test = []
#label_test = np.zeros(shape=(sign_loader_selected.__len__(),))
label_test = []
for i, (image_batch, label_batch) in enumerate(sign_loader_selected):
    if use_gpu:
        image_batch = image_batch.cuda()
        label_batch = label_batch.cuda()
    label_test.append(label_batch.detach().cpu().numpy())
    img_example = model.forward(image_batch)
    predictions_test.append(torch.softmax(img_example, dim=1).detach().cpu().numpy())

predictions_test = np.concatenate(predictions_test, axis = 0)
label_test = np.concatenate(label_test, axis = 0)
#print(predictions_test.shape)
#print(label_test)
#print(np.argmax(predictions_test, axis=0))
import itertools
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(label_test, np.argmax(predictions_test, axis = 1))
cm = cm/np.sum(cm, axis=1, keepdims=True)
classes = list('ABCDEFHIKLMNOPQRTUVWY')
fig, ax = plt.subplots(figsize=(10, 10), tight_layout=True)
ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.set_xticks(np.arange(len(classes))); 
ax.set_yticks(np.arange(len(classes)))
ax.set_xticklabels(classes); ax.set_yticklabels(classes)
ax.set_ylabel('True label'); ax.set_xlabel('Predicted label')
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], '.2f'),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

fig.savefig(c_matrix_file_path, dpi=fig.dpi)
# Out:
# /home/redbird/.local/lib/python3.5/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
Tensor = torch.cuda.FloatTensor

#Convert an image(source) to a Tensor
def image_to_tensor(img):
    image = cv2.imread(img)
    image = torch.tensor((np.asarray(image).T/255.).astype('float32'))
    image = image.unsqueeze(0)
    if use_gpu:
        image = image.cuda()
    return image

def plot_image(img_path):
    image = plt.imread(img_path)
    plt.imshow(image)
    tensor_image = image_to_tensor(img_path)
    tensor_lenet_image = model(tensor_image)
    detected_label, accuracy = detect_class(tensor_lenet_image)
    #print('Have turkeys' if detected_label == 'y' else 'No turkeys')
    #print('Accuracy: '+ str(accuracy*100) + '%')
    plt.title('Accuracy: '+ str(accuracy*100)[0:5] + '%')
    plt.suptitle(detected_label)

    
#Return the class of a Tensor image
def detect_class(tensor_image):
    max_value = torch.softmax(tensor_image, dim=1).detach().cpu().numpy().max()
    arg_max = torch.softmax(tensor_image, dim=1).detach().cpu().numpy().argmax()
    return classes[arg_max], max_value

def print_results(image):
    tensor_image = image_to_tensor(image)
    tensor_lenet_image = model(tensor_image)
    detected_label, accuracy = detect_class(tensor_lenet_image)
    print(detected_label)
    print('Accuracy: '+ str(accuracy*100)[0:5] + '%')

def get_feat_maps(tensor_image):
    f_map_1 = my_lenet_model.activation(my_lenet_model.conv1(tensor_image))
    f_map_2 = my_lenet_model.activation(my_lenet_model.conv2(f_map_1))
    adapool = my_lenet_model.adapool(f_map_2)
    view = adapool.view(adapool.size(0), -1)
    f_conn1 = my_lenet_model.activation(my_lenet_model.fc1(view))
    f_conn2 = my_lenet_model.activation(my_lenet_model.fc2(f_conn1))
    output = my_lenet_model.fc3(f_conn2)
    return f_map_1, f_map_2#, adapool, f_conn1

#Plot feature map from
def plot_feat_map(f_map):
    n_feat_map = f_map.shape[1]
    divisions = 16
    fig, axes = plt.subplots(nrows=divisions, ncols=divisions, figsize=(20, 20))
    for i in range(0, divisions):
        for j in range(0, divisions):
            index = j + (divisions * i)
            axes[i,j].imshow(f_map[0, index].detach().cpu().numpy())
            axes[i,j].axis('off')
    plt.show()
    
def test_image(img = ''):
    test_img_path = 'balanced/'
    if(img == ''):
        folder = partition.values()[2]
        r = random.randint(0, len(folder))
        img = test_img_path + partition.values()[1][r]
        print(img)
    tensor_image = image_to_tensor(img)
    plot_image(img)
    #print_results(img)
    feat_maps = get_feat_maps(tensor_image)
    for i in range(len(feat_maps)):
        plot_feat_map(feat_maps[i])
import random

def get_alexnet_feat_maps(tensor_image):
    #f_map = (model.features[1](tensor_image)).detach().cpu().numpy()
    cv1 = (model.features[0](tensor_image))
    ac1 = (model.features[1](cv1))
    pool1 = (model.features[2](ac1))
    cv2 = (model.features[3](pool1))
    ac2 = (model.features[4](cv2))
    pool2 = (model.features[5](ac2))
    cv3 = (model.features[6](pool2))
    ac3 = (model.features[7](cv3))
    cv4 = (model.features[8](ac3))
    ac4 = (model.features[9](cv4))
    cv5 = (model.features[10](ac4))
    ac5 = (model.features[11](cv5))
    pool3 = (model.features[12](ac5))
    #print(ac5.shape)
    #print(pool3.shape)
    avgpool = (model.avgpool(pool3))
    #print(avgpool.shape)
    #print(pool3)
    view = avgpool.view(avgpool.size(0), 256 * 6 * 6)
    drop1 = model.classifier[0](view)
    linear1 = model.classifier[1](drop1)
    ac6 = model.classifier[2](linear1)
    drop2 = model.classifier[3](ac6)
    linear2 = model.classifier[4](drop2)
    ac7 = model.classifier[5](linear2)
    output = model.classifier[6](ac7)
    show_layer_features(pool3)

    return pool3

def show_layer_features(output):
    #print(output)
    print("Output layer shape: ", output.shape)
    #print(output.argmax(dim = 1))
    
def test_PIL_image(test_img_path, img = ''):
    if(img == ''):
        #folder = partition.values()[2]
        #r = random.randint(0, len(folder))
        r = random.choice(os.listdir(test_img_path)) #change dir name to whatever
        #img = test_img_path + partition.values()[1][r]
        img = test_img_path + r
    #print(img)
    pil_image = Image.open(img)
    #print(pil_image)
    tensor_image = transform_test_image(pil_image)
    print("Transform shape ", tensor_image.shape)
    if use_gpu:
        tensor_image = tensor_image.cuda()
    tensor_lenet_image = model(tensor_image)
    image = plt.imread(img)
    plt.imshow(image)
    detected_label, accuracy = detect_class(tensor_lenet_image)
    #print('Have turkeys' if detected_label == 'y' else 'No turkeys')
    #print('Accuracy: '+ str(accuracy*100) + '%')
    plt.title('Accuracy: '+ str(accuracy*100)[0:5] + '%')
    plt.suptitle(detected_label)
    #print_results(img)
    feat_maps = get_alexnet_feat_maps(tensor_image)
    plot_feat_map(feat_maps)

def transform_test_image(pil_image):
    plt.imshow(pil_image)
    transformed_image = image_transforms['valid'](pil_image)
    
    transformed_image = transformed_image.unsqueeze(0)
    return transformed_image

import random

def test_external_image(img = ''):
    test_img_path = 'american/'
    if(img == ''):
        r = random.choice(os.listdir(test_img_path)) #change dir name to whatever
        img = test_img_path + r
    tensor_image = image_to_tensor(img)
    plot_image(img)
    #print_results(img)
    #feat_maps = get_feat_maps(tensor_image)
    #for i in range(len(feat_maps)):
    #    plot_feat_map(feat_maps[i])
    
def test_images():
    test_img_path = 'balanced/'
    for image in partition.values()[1]:
        img = test_img_path + image
        plot_image(img)
        print_results(img)

# %%
#Choose an random image and show the class
#img_test_path = 'reduced/n_2016-07-12 06-15-00 T.JPG'
#test_external_image()
test_img_path = 'american/'

test_PIL_image(test_img_path)
# Out:
# Transform shape  torch.Size([1, 3, 224, 224])
# Output layer shape:  torch.Size([1, 256, 26, 26])

# %%
#test_images()

# %%
#Feat map for external images(external folder)
image_folder = 'american/'
for filename in os.listdir(image_folder):
    img_example = image_folder + filename
    tensor_image = image_to_tensor(img_example)
    if use_gpu:
        tensor_image = tensor_image.cuda()
    feat_maps = get_feat_maps(tensor_image)
    for i in range(len(feat_maps)):
        plot_feat_map(feat_maps[i])    
    tensor_lenet_image = my_lenet_model(tensor_image)
    detected_label, accuracy = detect_class(tensor_lenet_image)
    #print(detected_label, accuracy)

# %%
#feat map for batch of images
sign_loader_selected = sign_loaders[1]
for i, (image_batch, label_batch) in enumerate(sign_loader_selected):
    if use_gpu:
        image_batch = image_batch.cuda()
    feat_maps = get_feat_maps(image_batch)
    for i in range(len(feat_maps)):
        if(label_batch.detach().numpy()[0] == 1):
            plot_feat_map(feat_maps[i])
